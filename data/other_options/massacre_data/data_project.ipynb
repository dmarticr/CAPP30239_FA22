# %%
import urllib
import pandas as pd
import geopandas as gpd
import numpy as np

# Sources:
# - https://micrositios.centrodememoriahistorica.gov.co/observatorio/portal-de-datos/base-de-datos/
# - https://www.kaggle.com/code/alfredomaussa/colombia-municipios

outfilename = "dta.xlsx"
dls = "https://micrositios.centrodememoriahistorica.gov.co/observatorio/download/casos-ma/?wpdmdl=1256&refresh=634c738ad4ba41665954698"
urllib.request.urlretrieve(dls, outfilename)
dta = pd.read_excel(outfilename)
#dta_geo = gpd.read_file("Municipios.json")
# Out:
# c:\Python\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
#dta_geo.head()

# %%
dta
# Out:
#       ID Caso ID Caso Relacionado   Año  Mes  Día Código DANE de Municipio  \
# 0      100649            CR030032  1998    1   25                    25530
# 1      102446                 NaN  2007   10   17                    27361
# 2      105517                 NaN  2005   12    7                    44430
# 3      105564                 NaN  2000    6   18                    44430
# 4      105630                 NaN  2002    6    2                    44430
# ...       ...                 ...   ...  ...  ...                      ...
# 4304    95261                 NaN  1996   12   26                    20060
# 4305    95566                 NaN  1998    9    9                    20400
# 4306    96825                 NaN  2002    9   10                    20750
# 4307    98130                 NaN  2002   10   31                    23466
# 4308    99901                 NaN  1988   10   23                    25258
#
# ...

# %%
dic_names = {"ID Caso": "ID",
             "ID Caso Relacionado": "RELATED_ID",
             "Año": "YEAR",
             "Mes": "MONTH",
             "Día": "DAY",
             "Código DANE de Municipio": "DPTOMPIO",
             "Municipio": "MPIO_CNMBR",
             "Departamento": "DEPARTMENT",
             "Región": "REGION",
             "Modalidad": "MODALITY",
             "Presunto Responsable": "RESPONSIBLE",
             "Descripción Presunto Responsable": "RESPONSIBLE_DESCRIPTION",
             "Abandono o Despojo Forzado de Tierras": "LAND_DISPOSSESSION",
             "Amenaza o Intimidación": "THREAT",
             "Ataque Contra Misión Médica": "MEDICAL_MISSION",
             "Confinamiento o Restricción a la Movilidad": "CONFINEMENT",
             "Desplazamiento Forzado": "DISPLACEMENT",
             "Extorsión": "EXTORTION",
             "Lesionados Civiles": "INJURIES",
             "Pillaje": "PLUNDER",
             "Tortura": "TORTURE",
             "Violencia Basada en Género": "GENDER_VIOLENCE",
             "Otro Hecho Simultáneo": "SIMULTANEOUS_EVENT",
             "Total de Víctimas del Caso": "VICTIMS",
             "Tipo de Armas": "WEAPONS",
             "Latitud": "LAT",
             "Longitud": "LON"}

modality_dic = {"RUTA": "ROUTE",
"ENGAÑO": "HOAX",
"ASALTO": "ASSAULT",
"SICARIATO": "CONTRACT KILLING",
"RETENCIÓN/EJECUCIÓN": "RETENTION/EXECUTION",
"DESCONOCIDA": "UNKNOWN",
"RETÉN": "CHECKPOINT",
"INTERCEPTACIÓN": "INTERCEPTION",
"ATAQUE INDISCRIMINADO": "INDISCRIMINATE ATTACK",
"FALSO POSITIVO": "FALSE POSITIVE",
"INCURSIÓN": "INCURSION",
"RESISTENCIA A LA RETENCIÓN": "RESIST RETENTION",
"ARMA DE FUEGO - USO DE QUEMICOS Y TIXICOS": "FIREARM - CHEMICALS_TOXICS",
"ARTEFACTO EXPLOSIVO": "EXPLOSIVES",
"ASFIXIA MEC NICA": "ASPHIXIA",
"MATERIAL INCENDIARIO": "INCENDIARY",
"MOTOSIERRA": "CHAINSAW",
"ND": "NOT AVAILABLE",
"OBJETO CONTUNDENTE": "BLUNT_OBJ",
"OBJETO CONTUNDENTE - USO DE QUEMICOS Y TIXICOS": "BLUNT_OBJ - CHEMICALS_TOXICS",
"USO DE QUEMICOS Y TIXICOS": "CHEMICALS_TOXICS"}

dta.rename(columns=dic_names, inplace=True)
dta = dta.replace({"RESPONSIBLE": responsible_dic})
dta = dta.replace({"MODALITY": modality_dic})
dta = dta.replace({"WEAPONS": weapons_dic})
dta['RESPONSIBLE_DESCRIPTION'] = dta['RESPONSIBLE_DESCRIPTION'].replace('NO IDENTIFICADO','NOT IDENTIFIED')
dta['RESPONSIBLE_DESCRIPTION'] = dta['RESPONSIBLE_DESCRIPTION'].replace('NO IDENTIFICADA','NOT IDENTIFIED')
dta['RESPONSIBLE_DESCRIPTION'] = dta['RESPONSIBLE_DESCRIPTION'].replace('NO APLICA','DO NOT APPLY')
dta.head()
# Out:
#        ID RELATED_ID  YEAR  MONTH  DAY DPTOMPIO   MPIO_CNMBR    DEPARTMENT  \
# 0  100649   CR030032  1998      1   25    25530  PARATEBUENO  CUNDINAMARCA
# 1  102446        NaN  2007     10   17    27361      ISTMINA         CHOCO
# 2  105517        NaN  2005     12    7    44430       MAICAO    LA GUAJIRA
# 3  105564        NaN  2000      6   18    44430       MAICAO    LA GUAJIRA
# 4  105630        NaN  2002      6    2    44430       MAICAO    LA GUAJIRA
#
#                REGION          MODALITY  ... EXTORTION INJURIES  PLUNDER  \
# 0  PIEDEMONTE LLANERO             ROUTE  ...       1.0      0.0      0.0
# 1   VALLE DE SAN JUAN              HOAX  ...       0.0      0.0      0.0
# 2        ALTA GUAJIRA           ASSAULT  ...       0.0      0.0      0.0
# 3        ALTA GUAJIRA  CONTRACT KILLING  ...       0.0      3.0      0.0
# 4        ALTA GUAJIRA  CONTRACT KILLING  ...       0.0      0.0      0.0
#
#    TORTURE  GENDER_VIOLENCE    SIMULTANEOUS_EVENT  VICTIMS  WEAPONS  \
# ...

# %%
#weapons_dic = {"ARMA CORTO PUNZANTE": pd.Series(["BLADE_WEAPONS"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO": pd.Series(["BLADE_WEAPONS","FIREARM"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO - ARTEFACTO EXPLOSIVO": pd.Series(["BLADE_WEAPONS","FIREARM","EXPLOSIVE_DEVICE"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO - ASFIXIA MEC NICA": pd.Series(["BLADE_WEAPONS","FIREARM","MECHANICAL ASPHIXIA"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO - MATERIAL INCENDIARIO": pd.Series(["BLADE_WEAPONS","FIREARM","INCENDIARY_MATERIAL"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO - MOTOSIERRA": pd.Series(["BLADE_WEAPONS","FIREARM","CHAINSAW"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO - OBJETO CONTUNDENTE": pd.Series(["BLADE_WEAPONS","FIREARM","BLUNT_OBJECT"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO - OTRO": pd.Series(["BLADE_WEAPONS","FIREARM","OTHER"]),
#    "ARMA CORTO PUNZANTE - ARMA DE FUEGO - USO DE QUEMICOS Y TIXICOS": pd.Series(["BLADE_WEAPONS","FIREARM","CHEMICALS_TOXICS"]),
#    "ARMA CORTO PUNZANTE - ASFIXIA MEC NICA": pd.Series(["BLADE_WEAPONS"]),
#    "ARMA CORTO PUNZANTE - OBJETO CONTUNDENTE": pd.Series(["BLADE_WEAPONS"]),
#    "ARMA CORTO PUNZANTE - OTRO": pd.Series(["BLADE_WEAPONS"]),
#    "ARMA CORTO PUNZANTE - USO DE QUEMICOS Y TIXICOS": pd.Series(["BLADE_WEAPONS"]),
#    "ARMA DE FUEGO": pd.Series(["FIREARM"]),
#    "ARMA DE FUEGO - ARTEFACTO EXPLOSIVO": pd.Series(["FIREARM","EXPLOSIVE_DEVICE"]),
#    "ARMA DE FUEGO - ARTEFACTO EXPLOSIVO - MATERIAL INCENDIARIO": pd.Series(["FIREARM","EXPLOSIVE_DEVICE","INCENDIARY_MATERIAL"]),
#    "ARMA DE FUEGO - ASFIXIA MEC NICA": pd.Series(["FIREARM","MECHANICAL ASPHIXIA"]),
#    "ARMA DE FUEGO - ASFIXIA MEC NICA - OBJETO CONTUNDENTE": pd.Series(["FIREARM","MECHANICAL ASPHIXIA","BLUNT_OBJECT"]),
#    "ARMA DE FUEGO - MATERIAL INCENDIARIO": pd.Series(["FIREARM","INCENDIARY_MATERIAL"]),
#    "ARMA DE FUEGO - MOTOSIERRA": pd.Series(["FIREARM","CHAINSAW"]),
#    "ARMA DE FUEGO - OBJETO CONTUNDENTE": pd.Series(["FIREARM","BLUNT_OBJECT"]),
#    "ARMA DE FUEGO - OTRO": pd.Series(["FIREARM","OTHER"]),
#    "ARMA DE FUEGO - USO DE QUEMICOS Y TIXICOS": pd.Series(["FIREARM","CHEMICALS_TOXICS"]),
#    "ARTEFACTO EXPLOSIVO": pd.Series(["EXPLOSIVE_DEVICE"]),
#    "ASFIXIA MEC NICA": pd.Series(["MECHANICAL ASPHIXIA"]),
#    "MATERIAL INCENDIARIO": pd.Series(["INCENDIARY_MATERIAL"]),
#    "MOTOSIERRA": pd.Series(["CHAINSAW"]),
#    "ND": pd.Series(["NOT_AVAILABLE"]),
#    "OBJETO CONTUNDENTE": pd.Series(["BLUNT_OBJECT"]),
#    "OBJETO CONTUNDENTE - USO DE QUEMICOS Y TIXICOS": pd.Series(["BLUNT_OBJECT","CHEMICALS_TOXICS"]),
#    "USO DE QUEMICOS Y TIXICOS": pd.Series(["CHEMICALS_TOXICS"])}

#dta = dta.replace({"WEAPONS": weapons_dic})

# %%
dta.to_csv('dta_t.csv', encoding = "ISO-8859-1")
